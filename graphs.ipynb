# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Linear Regression

# %%
features = ['Min', 'Max', 'Mean', 'Standard dev', 'Standardisation']
importance = [0.7190, -0.7750, -0.1934, -0.0622, -0.1977]  # Example feature importance

# Plot bar graph
plt.figure(figsize=(8, 5))
plt.bar(features, importance)

# Add labels and title


# Show the plot
plt.show()

# %% [markdown]
# ### Ridge Regression

# %%
features = ['Min', 'Max', 'Mean', 'Standard dev', 'Standardisation']
importance = [0.6940, -0.7749, -0.1935, -0.0592, -0.2112]  # Example feature importance

# Plot bar graph
plt.figure(figsize=(8, 5))
plt.bar(features, importance)

# Add labels and title


# Show the plot
plt.show()

# %% [markdown]
# ### Random Forest Regression

# %%
features = ['Min', 'Max', 'Mean', 'Standard dev', 'Standardisation']
importance = [0.9999, 0.9998, 0.9941, 0.8544, 0.9098]  # Example feature importance

# Plot bar graph
plt.figure(figsize=(8, 5))
plt.bar(features, importance)

# Add labels and title


# Show the plot
plt.show()

# %% [markdown]
# ### Decision Tree Regression

# %%
features = ['Min', 'Max', 'Mean', 'Standard dev', 'Standardisation']
importance = [0.9991, 0.9992, 0.9972, 0.6423, 0.7808]  # Example feature importance

# Plot bar graph
plt.figure(figsize=(8, 5))
plt.bar(features, importance)

# Add labels and title


# Show the plot
plt.show()

# %% [markdown]
# ### Lasso Regression

# %%
features = ['Min', 'Max', 'Mean', 'Standard dev', 'Standardisation']
importance = [0.6990, -0.7709, -0.2008, -0.0486, -0.7091]  # Example feature importance

# Plot bar graph
plt.figure(figsize=(8, 5))
plt.bar(features, importance)

# Add labels and title


# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample Data with Custom Row Names
data = {
    'Linear':[0.7190, -0.7750, -0.1934, -0.0622, -0.1977],
    'Ridge': [0.6940, -0.7749, -0.1935, -0.0592, -0.2112],
    'Random Forest': [0.9999, 0.9998, 0.9941, 0.8544, 0.9098],
    'Decision Tree': [0.9991, 0.9992, 0.9972, 0.6423, 0.7808],
    'Lasso': [0.6990, -0.7709, -0.2008, -0.0486, -0.7091]
}
row_names = ['Min', 'Max', 'Mean', 'Stand Dev', 'Standzn']

df = pd.DataFrame(data, index=row_names)

# Create Heatmap
sns.heatmap(df, annot=True, cmap='inferno')

# Display the plot
plt.title('Model Performance Metrics Heatmap')
plt.show()
